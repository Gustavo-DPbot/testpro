# %% [markdown]
# # My first Program

# %%
1+1
# Out:
# 2

# %%
49
# Out:
# 49

# %%
x= min(5,10,25)
y= max(5,10,25)

print(x)
print(y)
# Out:
# 5
# 25

# %%
x= pow(4,3)

print(x)
# Out:
# 64

# %%
2*3 #Multiplication
# Out:
# [1] 6

# %%
100-1 #subtraction
# Out:
# [1] 99

# %%
a<-1 # assigning 1 to the variable a
a+2 # adding 2
# Out:
# [1] 3

# %%
df = data.frame(Emp_Name = c("Jai", "Mendis", "Michael"),
                Job_role = c("Manager", "Team Lead", "Developer" )
             )

print(df)
# Out:
#   Emp_Name  Job_role
# 1      Jai   Manager
# 2   Mendis Team Lead
# 3  Michael Developer
